# %% [markdown]
# # Matthew Schelonka - Markdown Practice

# %% [markdown]
# ### I am from Indianapolis and I am an Accounting and Finance Major. My interest in coding started in high school where I took 2 computer science classes. I am taking a few more computer science classes now to develop my coding knowledge for use in the workplace.

# %% [markdown]
# - Programming Assignment (5) - 20%
# - Quizzes (4) - 10%
# - Attendance/Class Participation - 20%
# - Exams (2) - 30%
# - Projects (2) - 20%

# %% [markdown]
# 1. Module 1 - Introduction
# 2. Module 1 - Variables, Data Types, and Github
# 3. Module 2 - Lists and Tuples Part 1
# 4. Module 3 - If Statements
# 5. Module 4 - Loops
# 6. Module 5 - Lists and Tuples Part 2
# 7. Module 6 - Dictionaries
# 8. Module 7 - Sets, Functions, Libraries
# 9. Module 8 - Class Datatypes and Exceptions
# 10. Module 9 - NumPy Arrys
# 11. Module 10 - Pandas and Files Excerpt

# %% [markdown]
# **The primary coding language we will be using is Python**

# %% [markdown]
# *The software we are using to create .ipynb files is through Jupyter Notebook*

# %% [markdown]
# Today I went to Trader Joe's to do ```grocery shopping```

# %% [markdown]
# <https://github.com/mjschelonka-pixel>

# %% [markdown]
# ![python](Bellarmine-Knights-Symbol.png)

# %% [markdown]
# I learned how to use bold, italics, and highlight a certain block of words in a sentence. I also learned how to make bullet point and numbered lists, as well as reinforcing how to include images. Lastly, I learned how to create a hyperlink in python.
