# %% [markdown]
# # CS 150 Programming Assignment 2 - Matthew Schelonka - Fall 2026

# %% [markdown]
# ## Task 1 - Personal Information

# %%
myName = 'Matthew'
myAge = 21
myHeight = 70
myColor = 'purple'
print("My name is",myName, "I am",myAge, "years old, I am",myHeight, "inches tall, and my favorite color is",myColor, ".")
# Out:
# My name is Matthew I am 21 years old, I am 70 inches tall, and my favorite color is purple .

# %% [markdown]
# ## Task 2 - Distance Conversion

# %%
miles_distance = 64
kilometers_distance = miles_distance*1.60934
print('The distance is',miles_distance,'miles, which is equivalent to',kilometers_distance, 'kilometers.')
# Out:
# The distance is 64 miles, which is equivalent to 102.99776 kilometers.

# %% [markdown]
# ## Task 3 - Working with Running Times

# %%
run1 = 12
run2 = 8
print(run1+run2)
print(run1-run2)
print(run2*2)
totalTime=run1+run2
print(totalTime/2)
# Out:
# 20
# 4
# 16
# 10.0

# %% [markdown]
# ## Task 4 - String Manipulation

# %%
quote="Believe you can and you're halfway there"
print(len (quote))
print(quote.upper())
print(quote.lower())
print(quote.strip())
print(quote.split())
# Out:
# 40
# BELIEVE YOU CAN AND YOU'RE HALFWAY THERE
# believe you can and you're halfway there
# Believe you can and you're halfway there
# ['Believe', 'you', 'can', 'and', "you're", 'halfway', 'there']

# %% [markdown]
# ## Task 5 - User Input and Operations

# %%
leg1=float(input('Enter a number'))
leg2=float(input('Enter another number'))
leg3=(leg1**2+leg2**2)**0.5
print('The hypotenuse of your triangle is',round(leg3,2),'units.')
# Out:
# Enter a number 8
# Enter another number 4
# The hypotenuse of your triangle is 8.94 units.
